# %%
#STRINGS

# %%
st = "Hum honge kamyab, hum honge kamyab aik din"
print("---------------------------------------------------------------------------------------------------")
print(len(st))
print("-------")
print(st)
print("-------")
print(st[16])
print("-------")
print(st[35:42])
print("-------")
print(st[4:16])
print("-------")
print(st.index("Hum"))
print("-------")
print(st.count("hum"))
print("-------")
if 'LALALA' in st:
    print("true")
else:
    print("False")
print("--------")
if ',' in st:
    print("true")
else:
    print("False")
print("--------")
if 'kamyab' in st:
    print("true")
else:
    print("False")
print("--------")
print(st[35:])
print("--------")
print(st[-14:-8])
print("----------------------------------------------------------------------------------------------")
# Out:
# ---------------------------------------------------------------------------------------------------
# 42
# -------
# Hum honge kamyab, hum honge kamyab aik din
# -------
# ,
# -------
# aik din
# -------
# honge kamyab
# -------
# 0
# -------
# 1
# -------
# False
# --------
# true
# --------
# true
# --------
# aik din
# --------
# kamyab
# ----------------------------------------------------------------------------------------------

# %%
st1 = "Boom: SanDisk just dropped the world’s largest SD card"
copymessage = st1
print("-----------------------------------------------------------------------------------------------------------------")
print(copymessage[0:])
print("--------")
         
print("---------")
print(len(st1))
print("-------")
print(st1[47:54])
print("-------")
#memcheck = "LA"

if "LA" in st1:
    memcheck = "have"
else:
    memcheck = "not have"
print("--------------------------------------------------------------------------------")

print("New message 1 = ")
newstr = st1.center(100)
print(newstr)

print("---------------------------------------------------------------------------")
print("New message 2 = ", st1.replace(' ' , '*'))

print("---------------------------------------------------------------------------")
h = "have"
h1= "not have"
if "ped" in st1[14:17]:
    suffixcheck="have"
else:
    suffixcheck="not have"
print(suffixcheck)   
print("---------------------------------------------------------------------------")

if "1TB" in st1:
    print("have ")
else:
    print("have not")

print("---------------------------------------------------------------------------")
randmString=" "
size = len(st1)//2
for i in range(size , 37):
    randmString = randmString+st1[i]
print(randmString)

print("---------------------------------------------------------------------------")

#double the length
s = st1 *2
print(s)
s1 = s.replace(' ', '*')
#after replace
print(s1)


print("-------------------------------------------------------------------------------------------------------------------")
# Out:
# -----------------------------------------------------------------------------------------------------------------
# Boom: SanDisk just dropped the world’s largest SD card
# --------
# ---------
# 54
# -------
# SD card
# -------
# --------------------------------------------------------------------------------
# New message 1 =
#                        Boom: SanDisk just dropped the world’s largest SD card
# ---------------------------------------------------------------------------
# New message 2 =  Boom:*SanDisk*just*dropped*the*world’s*largest*SD*card
# ---------------------------------------------------------------------------
# not have
# ---------------------------------------------------------------------------
# have not
# ---------------------------------------------------------------------------
#  the world’
# ---------------------------------------------------------------------------
# ...
